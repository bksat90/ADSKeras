# %% [markdown]
# <a href="https://colab.research.google.com/github/bksat90/ADSKeras/blob/main/Keras_Assignment_Sep23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Applied Data Science 2 - Keras Assignment - 2023A
#
# In this assignment you will be building a script to classify images of animals. The assignment is broken up into sections and you need to complete each section successively. The sections are:
#
# 1. Data Processing
# 2. Model Definition
# 3. Model Training
# 4. Model Evaluation
#
# In addition to this coding exercise, you will also need to write a 1-2 page report analysing and critically evaluating you models results.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import PIL
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from sklearn.metrics import classification_report, confusion_matrix

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Processing

# %%
# CodeGrade Tag DataProc

label_dict = {'cat' : 0,
              'dog' : 1,
              'wild' : 2}

rev_label_dict = {0 : 'cat',
                  1 : 'dog',
                  2 : 'wild'}

# This function is provided to read in the image files from the folder on your
# Google Drive
def parse_image(filename):
  parts = tf.strings.split(filename, os.sep)
  label = parts[-2]
  label = tf.strings.to_number(label)

  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

img_loc = "/content/drive/MyDrive/Animals/Animals/"

train_list_ds = tf.data.Dataset.list_files(img_loc + "train/*/*")
valid_list_ds = tf.data.Dataset.list_files(img_loc + "val/*/*")

# %%
# for element in train_list_ds:
#   print(element)

# %% [markdown]
# **Create a function called "img_process" converts the images to float32 datatype and resizes them to 64x64 pixels.**

# %%
# CodeGrade Tag Ex1a
### Write a function called img_process, which takes in the image and label as
### inputs, converts the data type of the image to tf.float32, resizes the
### image to (64,64), and finally returns the image and labels.

def img_process(image, label):
  # image = tf.image.convert_image_dtype(image, dtype=tf.float32)
  image = tf.cast(image, tf.float32)
  image = tf.image.resize(image, size=[64,64])
  image = image / 255.0
  return image, label

# %% [markdown]
# **Using the tf.data API, load in the training and validation data. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1b
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 128. Use techniques like caching and
### prefetching to efficiently load the data.

train_ds = train_list_ds
val_ds = valid_list_ds

# Training images are parsed with the processing and augmentation functions
train_ds = (
    train_ds
    .shuffle(1000)
    .map(parse_image)
    .map(img_process)
    .prefetch(tf.data.AUTOTUNE)
    .batch(128)
    .cache()
)

# Validation images are only parsed with the processing function
val_ds = (
    val_ds
    .map(parse_image)
    .map(img_process)
    .prefetch(tf.data.AUTOTUNE)
    .batch(128)
    .cache()
)

# %% [markdown]
# # Model Definition
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture show in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a SoftMax activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        1216
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 10)                5130
#
# =================================================================
# Total params: 363146 (1.39 MB)
# Trainable params: 363146 (1.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
# ### of the convolutional layers.

# input layer
input_layer = layers.Input(shape=(64, 64, 3), name='Input')

# Convolutional layers
conv0 = layers.Conv2D(16, (5, 5), activation='relu', padding="same",
                      strides=(2,2), name='Conv0')(input_layer)
conv1 = layers.Conv2D(32, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv1')(conv0)
conv2 = layers.Conv2D(32, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv2')(conv1)
pool1 = layers.MaxPooling2D((2, 2), name='Pool1')(conv2)

conv3 = layers.Conv2D(64, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv3')(pool1)
conv4 = layers.Conv2D(64, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv4')(conv3)
pool2 = layers.MaxPooling2D((2, 2), name='Pool2')(conv4)

conv5 = layers.Conv2D(128, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv5')(pool2)
conv6 = layers.Conv2D(128, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv6')(conv5)
global_pool = layers.GlobalAveragePooling2D(name='GlobalPool')(conv6)

# Fully connected layers
fc1 = layers.Dense(512, activation='relu', name='FC1')(global_pool)

# Output layer
output_layer = layers.Dense(3, activation='softmax', name='Output')(fc1)

# Create the model
model = models.Model(inputs=input_layer, outputs=output_layer)

# %%
# CodeGrade Tag Ex2b
### Print the model summary and confirm is has the same architecture as the one
### provided.

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        1216
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 3)                 1539
#
# =================================================================
# Total params: 359555 (1.37 MB)
# Trainable params: 359555 (1.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Compile the model using the Adam Optimizer with a learning rate of ```5e-5```, ```sparse categorical crossentropy``` loss function, and ```accuracy``` metric.**

# %%
# CodeGrade Tag Ex2c

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Model Training
#
# **Create a Model Checkpoint Callback that saves the weights of the best performing epoch, based on the validation accuracy.**

# %%
# CodeGrade Tag Ex3a
### Create a ModelCheckpoint callback to store the bext weights from the model,
### based on the validation accuracy. Call this callback "checkpoint_callback"

checkpoint_filepath = '/content/checkpoint'

checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)

# %% [markdown]
# **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3b
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.01)

lr_callback = LearningRateScheduler(scheduler)

# %% [markdown]
# **Train the model for 100 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3c
### Train the model for 100 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

epoch_num=100

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epoch_num,
    callbacks=[checkpoint_callback, lr_callback]
)
# Out:
# Epoch 1/100
# 115/115 [==============================] - 121s 898ms/step - loss: 1.0831 - accuracy: 0.3741 - val_loss: 1.0206 - val_accuracy: 0.5040 - lr: 5.0000e-05
# Epoch 2/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.9489 - accuracy: 0.5113 - val_loss: 0.8999 - val_accuracy: 0.5467 - lr: 5.0000e-05
# Epoch 3/100
# 115/115 [==============================] - 3s 25ms/step - loss: 0.8631 - accuracy: 0.5615 - val_loss: 0.8260 - val_accuracy: 0.6013 - lr: 5.0000e-05
# Epoch 4/100
# 115/115 [==============================] - 3s 27ms/step - loss: 0.8138 - accuracy: 0.5941 - val_loss: 0.7906 - val_accuracy: 0.6213 - lr: 5.0000e-05
# Epoch 5/100
# 115/115 [==============================] - 3s 22ms/step - loss: 0.7751 - accuracy: 0.6285 - val_loss: 0.7538 - val_accuracy: 0.6413 - lr: 5.0000e-05
# Epoch 6/100
# 115/115 [==============================] - 4s 32ms/step - loss: 0.7289 - accuracy: 0.6684 - val_loss: 0.7125 - val_accuracy: 0.6553 - lr: 5.0000e-05
# Epoch 7/100
# 115/115 [==============================] - 3s 25ms/step - loss: 0.6764 - accuracy: 0.7013 - val_loss: 0.6509 - val_accuracy: 0.6973 - lr: 5.0000e-05
# Epoch 8/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.6312 - accuracy: 0.7231 - val_loss: 0.6082 - val_accuracy: 0.7227 - lr: 5.0000e-05
# Epoch 9/100
# 115/115 [==============================] - 3s 23ms/step - loss: 0.6003 - accuracy: 0.7403 - val_loss: 0.5846 - val_accuracy: 0.7300 - lr: 5.0000e-05
# Epoch 10/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.5763 - accuracy: 0.7551 - val_loss: 0.5648 - val_accuracy: 0.7367 - lr: 5.0000e-05
# Epoch 11/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.5566 - accuracy: 0.7644 - val_loss: 0.5482 - val_accuracy: 0.7420 - lr: 4.9502e-05
# Epoch 12/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.5398 - accuracy: 0.7709 - val_loss: 0.5329 - val_accuracy: 0.7527 - lr: 4.9010e-05
# Epoch 13/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.5256 - accuracy: 0.7783 - val_loss: 0.5179 - val_accuracy: 0.7627 - lr: 4.8522e-05
# Epoch 14/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.5137 - accuracy: 0.7837 - val_loss: 0.5030 - val_accuracy: 0.7767 - lr: 4.8039e-05
# Epoch 15/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.5026 - accuracy: 0.7897 - val_loss: 0.4902 - val_accuracy: 0.7887 - lr: 4.7561e-05
# Epoch 16/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4917 - accuracy: 0.7938 - val_loss: 0.4789 - val_accuracy: 0.7860 - lr: 4.7088e-05
# Epoch 17/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4811 - accuracy: 0.7999 - val_loss: 0.4687 - val_accuracy: 0.7933 - lr: 4.6620e-05
# Epoch 18/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.4711 - accuracy: 0.8053 - val_loss: 0.4589 - val_accuracy: 0.8033 - lr: 4.6156e-05
# Epoch 19/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.4618 - accuracy: 0.8108 - val_loss: 0.4496 - val_accuracy: 0.8100 - lr: 4.5697e-05
# Epoch 20/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.4529 - accuracy: 0.8151 - val_loss: 0.4404 - val_accuracy: 0.8147 - lr: 4.5242e-05
# Epoch 21/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.4444 - accuracy: 0.8192 - val_loss: 0.4315 - val_accuracy: 0.8220 - lr: 4.4792e-05
# Epoch 22/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.4362 - accuracy: 0.8229 - val_loss: 0.4230 - val_accuracy: 0.8293 - lr: 4.4346e-05
# Epoch 23/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4283 - accuracy: 0.8271 - val_loss: 0.4147 - val_accuracy: 0.8307 - lr: 4.3905e-05
# Epoch 24/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4206 - accuracy: 0.8315 - val_loss: 0.4069 - val_accuracy: 0.8340 - lr: 4.3468e-05
# Epoch 25/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4133 - accuracy: 0.8359 - val_loss: 0.3997 - val_accuracy: 0.8367 - lr: 4.3035e-05
# Epoch 26/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4062 - accuracy: 0.8387 - val_loss: 0.3923 - val_accuracy: 0.8393 - lr: 4.2607e-05
# Epoch 27/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.3994 - accuracy: 0.8420 - val_loss: 0.3855 - val_accuracy: 0.8453 - lr: 4.2183e-05
# Epoch 28/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.3928 - accuracy: 0.8442 - val_loss: 0.3789 - val_accuracy: 0.8480 - lr: 4.1764e-05
# Epoch 29/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3865 - accuracy: 0.8472 - val_loss: 0.3727 - val_accuracy: 0.8527 - lr: 4.1348e-05
# Epoch 30/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.3805 - accuracy: 0.8508 - val_loss: 0.3664 - val_accuracy: 0.8567 - lr: 4.0937e-05
# Epoch 31/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.3746 - accuracy: 0.8533 - val_loss: 0.3606 - val_accuracy: 0.8560 - lr: 4.0529e-05
# Epoch 32/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3689 - accuracy: 0.8561 - val_loss: 0.3550 - val_accuracy: 0.8600 - lr: 4.0126e-05
# Epoch 33/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.3635 - accuracy: 0.8588 - val_loss: 0.3496 - val_accuracy: 0.8607 - lr: 3.9727e-05
# Epoch 34/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.3582 - accuracy: 0.8610 - val_loss: 0.3445 - val_accuracy: 0.8660 - lr: 3.9331e-05
# Epoch 35/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.3531 - accuracy: 0.8630 - val_loss: 0.3395 - val_accuracy: 0.8667 - lr: 3.8940e-05
# Epoch 36/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3481 - accuracy: 0.8648 - val_loss: 0.3345 - val_accuracy: 0.8687 - lr: 3.8553e-05
# Epoch 37/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.3434 - accuracy: 0.8666 - val_loss: 0.3296 - val_accuracy: 0.8693 - lr: 3.8169e-05
# Epoch 38/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3387 - accuracy: 0.8690 - val_loss: 0.3249 - val_accuracy: 0.8700 - lr: 3.7789e-05
# Epoch 39/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.3341 - accuracy: 0.8714 - val_loss: 0.3203 - val_accuracy: 0.8747 - lr: 3.7413e-05
# Epoch 40/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.3297 - accuracy: 0.8736 - val_loss: 0.3160 - val_accuracy: 0.8773 - lr: 3.7041e-05
# Epoch 41/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.3255 - accuracy: 0.8748 - val_loss: 0.3116 - val_accuracy: 0.8813 - lr: 3.6672e-05
# Epoch 42/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3213 - accuracy: 0.8768 - val_loss: 0.3073 - val_accuracy: 0.8833 - lr: 3.6307e-05
# Epoch 43/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3174 - accuracy: 0.8794 - val_loss: 0.3032 - val_accuracy: 0.8873 - lr: 3.5946e-05
# Epoch 44/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.3135 - accuracy: 0.8811 - val_loss: 0.2993 - val_accuracy: 0.8887 - lr: 3.5589e-05
# Epoch 45/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3097 - accuracy: 0.8829 - val_loss: 0.2955 - val_accuracy: 0.8900 - lr: 3.5234e-05
# Epoch 46/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.3062 - accuracy: 0.8849 - val_loss: 0.2914 - val_accuracy: 0.8907 - lr: 3.4884e-05
# Epoch 47/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.3027 - accuracy: 0.8865 - val_loss: 0.2877 - val_accuracy: 0.8927 - lr: 3.4537e-05
# Epoch 48/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2992 - accuracy: 0.8885 - val_loss: 0.2840 - val_accuracy: 0.8953 - lr: 3.4193e-05
# Epoch 49/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2960 - accuracy: 0.8908 - val_loss: 0.2805 - val_accuracy: 0.8960 - lr: 3.3853e-05
# Epoch 50/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2928 - accuracy: 0.8918 - val_loss: 0.2772 - val_accuracy: 0.8980 - lr: 3.3516e-05
# Epoch 51/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2897 - accuracy: 0.8930 - val_loss: 0.2739 - val_accuracy: 0.8987 - lr: 3.3183e-05
# Epoch 52/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2868 - accuracy: 0.8941 - val_loss: 0.2708 - val_accuracy: 0.8973 - lr: 3.2852e-05
# Epoch 53/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2839 - accuracy: 0.8950 - val_loss: 0.2679 - val_accuracy: 0.8993 - lr: 3.2525e-05
# Epoch 54/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2811 - accuracy: 0.8956 - val_loss: 0.2651 - val_accuracy: 0.9000 - lr: 3.2202e-05
# Epoch 55/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2784 - accuracy: 0.8967 - val_loss: 0.2624 - val_accuracy: 0.9020 - lr: 3.1881e-05
# Epoch 56/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2758 - accuracy: 0.8982 - val_loss: 0.2600 - val_accuracy: 0.9020 - lr: 3.1564e-05
# Epoch 57/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2732 - accuracy: 0.8992 - val_loss: 0.2577 - val_accuracy: 0.9040 - lr: 3.1250e-05
# Epoch 58/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2707 - accuracy: 0.9006 - val_loss: 0.2554 - val_accuracy: 0.9033 - lr: 3.0939e-05
# Epoch 59/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2682 - accuracy: 0.9014 - val_loss: 0.2533 - val_accuracy: 0.9067 - lr: 3.0631e-05
# Epoch 60/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2658 - accuracy: 0.9025 - val_loss: 0.2513 - val_accuracy: 0.9080 - lr: 3.0327e-05
# Epoch 61/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2635 - accuracy: 0.9023 - val_loss: 0.2495 - val_accuracy: 0.9107 - lr: 3.0025e-05
# Epoch 62/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2613 - accuracy: 0.9034 - val_loss: 0.2477 - val_accuracy: 0.9127 - lr: 2.9726e-05
# Epoch 63/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2591 - accuracy: 0.9046 - val_loss: 0.2463 - val_accuracy: 0.9140 - lr: 2.9430e-05
# Epoch 64/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2570 - accuracy: 0.9060 - val_loss: 0.2450 - val_accuracy: 0.9147 - lr: 2.9137e-05
# Epoch 65/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2549 - accuracy: 0.9065 - val_loss: 0.2437 - val_accuracy: 0.9147 - lr: 2.8847e-05
# Epoch 66/100
# 115/115 [==============================] - 3s 27ms/step - loss: 0.2528 - accuracy: 0.9076 - val_loss: 0.2426 - val_accuracy: 0.9153 - lr: 2.8560e-05
# Epoch 67/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2507 - accuracy: 0.9079 - val_loss: 0.2415 - val_accuracy: 0.9180 - lr: 2.8276e-05
# Epoch 68/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2487 - accuracy: 0.9083 - val_loss: 0.2404 - val_accuracy: 0.9180 - lr: 2.7995e-05
# Epoch 69/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2466 - accuracy: 0.9088 - val_loss: 0.2393 - val_accuracy: 0.9180 - lr: 2.7716e-05
# Epoch 70/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2446 - accuracy: 0.9094 - val_loss: 0.2383 - val_accuracy: 0.9193 - lr: 2.7441e-05
# Epoch 71/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2426 - accuracy: 0.9098 - val_loss: 0.2372 - val_accuracy: 0.9200 - lr: 2.7168e-05
# Epoch 72/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2406 - accuracy: 0.9108 - val_loss: 0.2361 - val_accuracy: 0.9200 - lr: 2.6897e-05
# Epoch 73/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2388 - accuracy: 0.9116 - val_loss: 0.2350 - val_accuracy: 0.9200 - lr: 2.6630e-05
# Epoch 74/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2369 - accuracy: 0.9122 - val_loss: 0.2339 - val_accuracy: 0.9207 - lr: 2.6365e-05
# Epoch 75/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2351 - accuracy: 0.9131 - val_loss: 0.2328 - val_accuracy: 0.9207 - lr: 2.6102e-05
# Epoch 76/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2334 - accuracy: 0.9135 - val_loss: 0.2319 - val_accuracy: 0.9207 - lr: 2.5843e-05
# Epoch 77/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2317 - accuracy: 0.9144 - val_loss: 0.2310 - val_accuracy: 0.9213 - lr: 2.5585e-05
# Epoch 78/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2300 - accuracy: 0.9152 - val_loss: 0.2301 - val_accuracy: 0.9213 - lr: 2.5331e-05
# Epoch 79/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.2283 - accuracy: 0.9161 - val_loss: 0.2291 - val_accuracy: 0.9220 - lr: 2.5079e-05
# Epoch 80/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2267 - accuracy: 0.9168 - val_loss: 0.2282 - val_accuracy: 0.9220 - lr: 2.4829e-05
# Epoch 81/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2251 - accuracy: 0.9171 - val_loss: 0.2273 - val_accuracy: 0.9220 - lr: 2.4582e-05
# Epoch 82/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2236 - accuracy: 0.9174 - val_loss: 0.2264 - val_accuracy: 0.9220 - lr: 2.4338e-05
# Epoch 83/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2220 - accuracy: 0.9180 - val_loss: 0.2255 - val_accuracy: 0.9227 - lr: 2.4095e-05
# Epoch 84/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2205 - accuracy: 0.9188 - val_loss: 0.2246 - val_accuracy: 0.9227 - lr: 2.3856e-05
# Epoch 85/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2191 - accuracy: 0.9197 - val_loss: 0.2238 - val_accuracy: 0.9227 - lr: 2.3618e-05
# Epoch 86/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2177 - accuracy: 0.9202 - val_loss: 0.2231 - val_accuracy: 0.9220 - lr: 2.3383e-05
# Epoch 87/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2163 - accuracy: 0.9208 - val_loss: 0.2224 - val_accuracy: 0.9227 - lr: 2.3151e-05
# Epoch 88/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2150 - accuracy: 0.9214 - val_loss: 0.2217 - val_accuracy: 0.9240 - lr: 2.2920e-05
# Epoch 89/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2137 - accuracy: 0.9217 - val_loss: 0.2209 - val_accuracy: 0.9247 - lr: 2.2692e-05
# Epoch 90/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2124 - accuracy: 0.9222 - val_loss: 0.2203 - val_accuracy: 0.9247 - lr: 2.2466e-05
# Epoch 91/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2111 - accuracy: 0.9227 - val_loss: 0.2197 - val_accuracy: 0.9253 - lr: 2.2243e-05
# Epoch 92/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2099 - accuracy: 0.9232 - val_loss: 0.2192 - val_accuracy: 0.9260 - lr: 2.2022e-05
# Epoch 93/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2087 - accuracy: 0.9235 - val_loss: 0.2187 - val_accuracy: 0.9260 - lr: 2.1802e-05
# Epoch 94/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2076 - accuracy: 0.9239 - val_loss: 0.2184 - val_accuracy: 0.9273 - lr: 2.1586e-05
# Epoch 95/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2065 - accuracy: 0.9241 - val_loss: 0.2179 - val_accuracy: 0.9273 - lr: 2.1371e-05
# Epoch 96/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2054 - accuracy: 0.9246 - val_loss: 0.2176 - val_accuracy: 0.9267 - lr: 2.1158e-05
# Epoch 97/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2043 - accuracy: 0.9252 - val_loss: 0.2172 - val_accuracy: 0.9273 - lr: 2.0948e-05
# Epoch 98/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2033 - accuracy: 0.9255 - val_loss: 0.2167 - val_accuracy: 0.9287 - lr: 2.0739e-05
# Epoch 99/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2023 - accuracy: 0.9261 - val_loss: 0.2165 - val_accuracy: 0.9300 - lr: 2.0533e-05
# Epoch 100/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2013 - accuracy: 0.9264 - val_loss: 0.2162 - val_accuracy: 0.9300 - lr: 2.0328e-05

# %% [markdown]
# # Model Evaluation
#
# **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the models performance.**

# %%
# CodeGrade Tag Ex4a

plt.figure()
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend(loc=0)
plt.title('Model Loss')

plt.figure()
plt.plot(history.history['accuracy'], label='Training')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend(loc=0)
plt.title('Model Accuracy')

plt.show()

# %% [markdown]
# **Load the best weights from your model checkpoint, and create plots demonstrating the classification perfomnce for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %%
# CodeGrade Tag Ex4b
model.load_weights(checkpoint_filepath)

y_true = np.concatenate([y for x,y in val_ds])
y_pred = np.argmax(model.predict(val_ds), axis=1)

print(classification_report(y_true, y_pred, target_names = label_dict.keys()))
print(confusion_matrix(y_true, y_pred))

f, ax = plt.subplots(5,5, figsize=(10, 12))
ax = ax.flatten()

x_val = np.concatenate([x for x,y in val_ds])

for i in range(25):
    ax[i].imshow(x_val[i])
    ax[i].set_title(f'Truth = {rev_label_dict[int(y_true[i])]}\nPred = {rev_label_dict[int(y_pred[i])]}')
    ax[i].set_xticks([])
    ax[i].set_yticks([])

plt.show()
# Out:
# 12/12 [==============================] - 0s 6ms/step
#               precision    recall  f1-score   support
#
#          cat       0.97      0.93      0.95       500
#          dog       0.89      0.95      0.92       500
#         wild       0.94      0.91      0.92       500
#
#     accuracy                           0.93      1500
#    macro avg       0.93      0.93      0.93      1500
# weighted avg       0.93      0.93      0.93      1500
#
# [[466  19  15]
#  [ 12 474  14]
#  [  4  41 455]]
