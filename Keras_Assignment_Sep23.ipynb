# %% [markdown]
# <a href="https://colab.research.google.com/github/bksat90/ADSKeras/blob/main/Keras_Assignment_Sep23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Applied Data Science 2 - Keras Assignment - 2023A
#
# In this assignment you will be building a script to classify images of animals. The assignment is broken up into sections and you need to complete each section successively. The sections are:
#
# 1. Data Processing
# 2. Model Definition
# 3. Model Training
# 4. Model Evaluation
#
# In addition to this coding exercise, you will also need to write a 1-2 page report analysing and critically evaluating you models results.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import PIL
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from sklearn.metrics import classification_report, confusion_matrix

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Processing

# %%
# CodeGrade Tag DataProc

label_dict = {'cat' : 0,
              'dog' : 1,
              'wild' : 2}

rev_label_dict = {0 : 'cat',
                  1 : 'dog',
                  2 : 'wild'}

# This function is provided to read in the image files from the folder on your
# Google Drive
def parse_image(filename):
  parts = tf.strings.split(filename, os.sep)
  label = parts[-2]
  label = tf.strings.to_number(label)

  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

img_loc = "/content/drive/MyDrive/Animals/Animals/"

train_list_ds = tf.data.Dataset.list_files(img_loc + "train/*/*")
valid_list_ds = tf.data.Dataset.list_files(img_loc + "val/*/*")

# %% [markdown]
# **Create a function called "img_process" converts the images to float32 datatype and resizes them to 64x64 pixels.**

# %%
# CodeGrade Tag Ex1a
### Write a function called img_process, which takes in the image and label as
### inputs, converts the data type of the image to tf.float32, resizes the
### image to (64,64), and finally returns the image and labels.

def img_process(image, label):
  # image = tf.image.convert_image_dtype(image, dtype=tf.float32)
  image = tf.cast(image, tf.float32)
  image = tf.image.resize(image, size=[64,64])
  image = image / 255.0
  return image, label

# %% [markdown]
# **Using the tf.data API, load in the training and validation data. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1b
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 128. Use techniques like caching and
### prefetching to efficiently load the data.

train_ds = train_list_ds
val_ds = valid_list_ds

# Training images are parsed with the processing and augmentation functions
train_ds = (
    train_ds
    .shuffle(1000)
    .map(parse_image)
    .map(img_process)
    .prefetch(tf.data.AUTOTUNE)
    .batch(128)
    .cache()
)

# Validation images are only parsed with the processing function
val_ds = (
    val_ds
    .map(parse_image)
    .map(img_process)
    .prefetch(tf.data.AUTOTUNE)
    .batch(128)
    .cache()
)

# %% [markdown]
# # Model Definition
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture show in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a SoftMax activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        1216
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 10)                5130
#
# =================================================================
# Total params: 363146 (1.39 MB)
# Trainable params: 363146 (1.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
# ### of the convolutional layers.

# input layer
input_layer = layers.Input(shape=(64, 64, 3), name='Input')

# Convolutional layers
conv0 = layers.Conv2D(16, (5, 5), activation='relu', padding="same",
                      strides=(2,2), name='Conv0')(input_layer)
conv1 = layers.Conv2D(32, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv1')(conv0)
conv2 = layers.Conv2D(32, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv2')(conv1)
pool1 = layers.MaxPooling2D((2, 2), name='Pool1')(conv2)

conv3 = layers.Conv2D(64, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv3')(pool1)
conv4 = layers.Conv2D(64, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv4')(conv3)
pool2 = layers.MaxPooling2D((2, 2), name='Pool2')(conv4)

conv5 = layers.Conv2D(128, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv5')(pool2)
conv6 = layers.Conv2D(128, (3, 3), activation='relu', padding="same",
                      strides=(1,1), name='Conv6')(conv5)
global_pool = layers.GlobalAveragePooling2D(name='GlobalPool')(conv6)

# Fully connected layers
fc1 = layers.Dense(512, activation='relu', name='FC1')(global_pool)

# Output layer
output_layer = layers.Dense(3, activation='softmax', name='Output')(fc1)

# Create the model
model = models.Model(inputs=input_layer, outputs=output_layer)

# %%
# CodeGrade Tag Ex2b
### Print the model summary and confirm is has the same architecture as the one
### provided.

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        1216
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 3)                 1539
#
# =================================================================
# Total params: 359555 (1.37 MB)
# Trainable params: 359555 (1.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Compile the model using the Adam Optimizer with a learning rate of ```5e-5```, ```sparse categorical crossentropy``` loss function, and ```accuracy``` metric.**

# %%
# CodeGrade Tag Ex2c

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Model Training
#
# **Create a Model Checkpoint Callback that saves the weights of the best performing epoch, based on the validation accuracy.**

# %%
# CodeGrade Tag Ex3a
### Create a ModelCheckpoint callback to store the bext weights from the model,
### based on the validation accuracy. Call this callback "checkpoint_callback"

checkpoint_filepath = '/content/checkpoint'

checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)

# %% [markdown]
# **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3b
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.01)

lr_callback = LearningRateScheduler(scheduler)

# %% [markdown]
# **Train the model for 100 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3c
### Train the model for 100 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

epoch_num=100

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epoch_num,
    callbacks=[checkpoint_callback, lr_callback]
)
# Out:
# Epoch 1/100
# 115/115 [==============================] - 129s 932ms/step - loss: 1.0808 - accuracy: 0.3905 - val_loss: 1.0202 - val_accuracy: 0.4953 - lr: 5.0000e-05
# Epoch 2/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.9504 - accuracy: 0.5188 - val_loss: 0.9487 - val_accuracy: 0.5020 - lr: 5.0000e-05
# Epoch 3/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.8677 - accuracy: 0.5581 - val_loss: 0.8682 - val_accuracy: 0.5520 - lr: 5.0000e-05
# Epoch 4/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.8287 - accuracy: 0.5834 - val_loss: 0.8239 - val_accuracy: 0.5833 - lr: 5.0000e-05
# Epoch 5/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.8051 - accuracy: 0.6024 - val_loss: 0.7960 - val_accuracy: 0.6073 - lr: 5.0000e-05
# Epoch 6/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.7822 - accuracy: 0.6193 - val_loss: 0.7675 - val_accuracy: 0.6273 - lr: 5.0000e-05
# Epoch 7/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.7527 - accuracy: 0.6469 - val_loss: 0.7329 - val_accuracy: 0.6473 - lr: 5.0000e-05
# Epoch 8/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.7135 - accuracy: 0.6794 - val_loss: 0.7000 - val_accuracy: 0.6707 - lr: 5.0000e-05
# Epoch 9/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.6738 - accuracy: 0.6968 - val_loss: 0.6655 - val_accuracy: 0.6920 - lr: 5.0000e-05
# Epoch 10/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.6438 - accuracy: 0.7162 - val_loss: 0.6318 - val_accuracy: 0.7113 - lr: 5.0000e-05
# Epoch 11/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.6210 - accuracy: 0.7269 - val_loss: 0.6092 - val_accuracy: 0.7260 - lr: 4.9502e-05
# Epoch 12/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.6019 - accuracy: 0.7372 - val_loss: 0.5906 - val_accuracy: 0.7393 - lr: 4.9010e-05
# Epoch 13/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.5856 - accuracy: 0.7456 - val_loss: 0.5735 - val_accuracy: 0.7507 - lr: 4.8522e-05
# Epoch 14/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.5710 - accuracy: 0.7535 - val_loss: 0.5581 - val_accuracy: 0.7627 - lr: 4.8039e-05
# Epoch 15/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.5581 - accuracy: 0.7596 - val_loss: 0.5440 - val_accuracy: 0.7707 - lr: 4.7561e-05
# Epoch 16/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.5462 - accuracy: 0.7672 - val_loss: 0.5312 - val_accuracy: 0.7807 - lr: 4.7088e-05
# Epoch 17/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.5352 - accuracy: 0.7723 - val_loss: 0.5190 - val_accuracy: 0.7880 - lr: 4.6620e-05
# Epoch 18/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.5247 - accuracy: 0.7783 - val_loss: 0.5079 - val_accuracy: 0.7920 - lr: 4.6156e-05
# Epoch 19/100
# 115/115 [==============================] - 3s 24ms/step - loss: 0.5149 - accuracy: 0.7824 - val_loss: 0.4970 - val_accuracy: 0.7973 - lr: 4.5697e-05
# Epoch 20/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.5053 - accuracy: 0.7852 - val_loss: 0.4864 - val_accuracy: 0.8013 - lr: 4.5242e-05
# Epoch 21/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4959 - accuracy: 0.7907 - val_loss: 0.4764 - val_accuracy: 0.8060 - lr: 4.4792e-05
# Epoch 22/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4868 - accuracy: 0.7950 - val_loss: 0.4666 - val_accuracy: 0.8113 - lr: 4.4346e-05
# Epoch 23/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4780 - accuracy: 0.8000 - val_loss: 0.4564 - val_accuracy: 0.8147 - lr: 4.3905e-05
# Epoch 24/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.4693 - accuracy: 0.8043 - val_loss: 0.4459 - val_accuracy: 0.8200 - lr: 4.3468e-05
# Epoch 25/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.4606 - accuracy: 0.8090 - val_loss: 0.4347 - val_accuracy: 0.8227 - lr: 4.3035e-05
# Epoch 26/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.4522 - accuracy: 0.8141 - val_loss: 0.4239 - val_accuracy: 0.8300 - lr: 4.2607e-05
# Epoch 27/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4440 - accuracy: 0.8171 - val_loss: 0.4136 - val_accuracy: 0.8353 - lr: 4.2183e-05
# Epoch 28/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4361 - accuracy: 0.8200 - val_loss: 0.4042 - val_accuracy: 0.8413 - lr: 4.1764e-05
# Epoch 29/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4282 - accuracy: 0.8240 - val_loss: 0.3953 - val_accuracy: 0.8433 - lr: 4.1348e-05
# Epoch 30/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.4207 - accuracy: 0.8278 - val_loss: 0.3872 - val_accuracy: 0.8480 - lr: 4.0937e-05
# Epoch 31/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.4133 - accuracy: 0.8317 - val_loss: 0.3798 - val_accuracy: 0.8520 - lr: 4.0529e-05
# Epoch 32/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.4062 - accuracy: 0.8350 - val_loss: 0.3728 - val_accuracy: 0.8580 - lr: 4.0126e-05
# Epoch 33/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3992 - accuracy: 0.8388 - val_loss: 0.3665 - val_accuracy: 0.8607 - lr: 3.9727e-05
# Epoch 34/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.3925 - accuracy: 0.8423 - val_loss: 0.3603 - val_accuracy: 0.8640 - lr: 3.9331e-05
# Epoch 35/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3858 - accuracy: 0.8454 - val_loss: 0.3546 - val_accuracy: 0.8667 - lr: 3.8940e-05
# Epoch 36/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3795 - accuracy: 0.8485 - val_loss: 0.3491 - val_accuracy: 0.8687 - lr: 3.8553e-05
# Epoch 37/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.3734 - accuracy: 0.8521 - val_loss: 0.3442 - val_accuracy: 0.8713 - lr: 3.8169e-05
# Epoch 38/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.3676 - accuracy: 0.8547 - val_loss: 0.3394 - val_accuracy: 0.8727 - lr: 3.7789e-05
# Epoch 39/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.3620 - accuracy: 0.8576 - val_loss: 0.3349 - val_accuracy: 0.8733 - lr: 3.7413e-05
# Epoch 40/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3566 - accuracy: 0.8600 - val_loss: 0.3306 - val_accuracy: 0.8767 - lr: 3.7041e-05
# Epoch 41/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3514 - accuracy: 0.8626 - val_loss: 0.3265 - val_accuracy: 0.8807 - lr: 3.6672e-05
# Epoch 42/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3464 - accuracy: 0.8641 - val_loss: 0.3226 - val_accuracy: 0.8820 - lr: 3.6307e-05
# Epoch 43/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3416 - accuracy: 0.8660 - val_loss: 0.3189 - val_accuracy: 0.8800 - lr: 3.5946e-05
# Epoch 44/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.3369 - accuracy: 0.8680 - val_loss: 0.3154 - val_accuracy: 0.8813 - lr: 3.5589e-05
# Epoch 45/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.3324 - accuracy: 0.8701 - val_loss: 0.3118 - val_accuracy: 0.8820 - lr: 3.5234e-05
# Epoch 46/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3281 - accuracy: 0.8726 - val_loss: 0.3086 - val_accuracy: 0.8827 - lr: 3.4884e-05
# Epoch 47/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3240 - accuracy: 0.8742 - val_loss: 0.3055 - val_accuracy: 0.8847 - lr: 3.4537e-05
# Epoch 48/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3200 - accuracy: 0.8759 - val_loss: 0.3025 - val_accuracy: 0.8860 - lr: 3.4193e-05
# Epoch 49/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.3161 - accuracy: 0.8779 - val_loss: 0.2997 - val_accuracy: 0.8867 - lr: 3.3853e-05
# Epoch 50/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.3124 - accuracy: 0.8790 - val_loss: 0.2969 - val_accuracy: 0.8867 - lr: 3.3516e-05
# Epoch 51/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.3088 - accuracy: 0.8805 - val_loss: 0.2944 - val_accuracy: 0.8867 - lr: 3.3183e-05
# Epoch 52/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.3053 - accuracy: 0.8822 - val_loss: 0.2919 - val_accuracy: 0.8860 - lr: 3.2852e-05
# Epoch 53/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3019 - accuracy: 0.8831 - val_loss: 0.2895 - val_accuracy: 0.8880 - lr: 3.2525e-05
# Epoch 54/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2987 - accuracy: 0.8847 - val_loss: 0.2871 - val_accuracy: 0.8887 - lr: 3.2202e-05
# Epoch 55/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2955 - accuracy: 0.8858 - val_loss: 0.2848 - val_accuracy: 0.8880 - lr: 3.1881e-05
# Epoch 56/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2925 - accuracy: 0.8873 - val_loss: 0.2826 - val_accuracy: 0.8887 - lr: 3.1564e-05
# Epoch 57/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2896 - accuracy: 0.8887 - val_loss: 0.2804 - val_accuracy: 0.8900 - lr: 3.1250e-05
# Epoch 58/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2867 - accuracy: 0.8902 - val_loss: 0.2785 - val_accuracy: 0.8900 - lr: 3.0939e-05
# Epoch 59/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2840 - accuracy: 0.8912 - val_loss: 0.2767 - val_accuracy: 0.8893 - lr: 3.0631e-05
# Epoch 60/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2813 - accuracy: 0.8924 - val_loss: 0.2750 - val_accuracy: 0.8900 - lr: 3.0327e-05
# Epoch 61/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2787 - accuracy: 0.8941 - val_loss: 0.2734 - val_accuracy: 0.8913 - lr: 3.0025e-05
# Epoch 62/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2762 - accuracy: 0.8954 - val_loss: 0.2717 - val_accuracy: 0.8913 - lr: 2.9726e-05
# Epoch 63/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.2737 - accuracy: 0.8965 - val_loss: 0.2701 - val_accuracy: 0.8927 - lr: 2.9430e-05
# Epoch 64/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2713 - accuracy: 0.8980 - val_loss: 0.2684 - val_accuracy: 0.8927 - lr: 2.9137e-05
# Epoch 65/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2689 - accuracy: 0.8993 - val_loss: 0.2671 - val_accuracy: 0.8940 - lr: 2.8847e-05
# Epoch 66/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2667 - accuracy: 0.9003 - val_loss: 0.2657 - val_accuracy: 0.8947 - lr: 2.8560e-05
# Epoch 67/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2644 - accuracy: 0.9014 - val_loss: 0.2644 - val_accuracy: 0.8953 - lr: 2.8276e-05
# Epoch 68/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2623 - accuracy: 0.9024 - val_loss: 0.2632 - val_accuracy: 0.8953 - lr: 2.7995e-05
# Epoch 69/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2602 - accuracy: 0.9031 - val_loss: 0.2620 - val_accuracy: 0.8947 - lr: 2.7716e-05
# Epoch 70/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2582 - accuracy: 0.9034 - val_loss: 0.2608 - val_accuracy: 0.8947 - lr: 2.7441e-05
# Epoch 71/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.2561 - accuracy: 0.9046 - val_loss: 0.2598 - val_accuracy: 0.8953 - lr: 2.7168e-05
# Epoch 72/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2542 - accuracy: 0.9053 - val_loss: 0.2585 - val_accuracy: 0.8947 - lr: 2.6897e-05
# Epoch 73/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2522 - accuracy: 0.9067 - val_loss: 0.2575 - val_accuracy: 0.8953 - lr: 2.6630e-05
# Epoch 74/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2504 - accuracy: 0.9075 - val_loss: 0.2564 - val_accuracy: 0.8953 - lr: 2.6365e-05
# Epoch 75/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2485 - accuracy: 0.9082 - val_loss: 0.2554 - val_accuracy: 0.8967 - lr: 2.6102e-05
# Epoch 76/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2467 - accuracy: 0.9091 - val_loss: 0.2544 - val_accuracy: 0.8987 - lr: 2.5843e-05
# Epoch 77/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.2448 - accuracy: 0.9097 - val_loss: 0.2532 - val_accuracy: 0.8993 - lr: 2.5585e-05
# Epoch 78/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2430 - accuracy: 0.9105 - val_loss: 0.2521 - val_accuracy: 0.8993 - lr: 2.5331e-05
# Epoch 79/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2413 - accuracy: 0.9114 - val_loss: 0.2511 - val_accuracy: 0.9000 - lr: 2.5079e-05
# Epoch 80/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2396 - accuracy: 0.9119 - val_loss: 0.2502 - val_accuracy: 0.9007 - lr: 2.4829e-05
# Epoch 81/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2379 - accuracy: 0.9124 - val_loss: 0.2494 - val_accuracy: 0.9013 - lr: 2.4582e-05
# Epoch 82/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2363 - accuracy: 0.9134 - val_loss: 0.2486 - val_accuracy: 0.9027 - lr: 2.4338e-05
# Epoch 83/100
# 115/115 [==============================] - 2s 21ms/step - loss: 0.2348 - accuracy: 0.9137 - val_loss: 0.2479 - val_accuracy: 0.9033 - lr: 2.4095e-05
# Epoch 84/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2333 - accuracy: 0.9142 - val_loss: 0.2472 - val_accuracy: 0.9027 - lr: 2.3856e-05
# Epoch 85/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2317 - accuracy: 0.9145 - val_loss: 0.2463 - val_accuracy: 0.9033 - lr: 2.3618e-05
# Epoch 86/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2303 - accuracy: 0.9150 - val_loss: 0.2456 - val_accuracy: 0.9040 - lr: 2.3383e-05
# Epoch 87/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2288 - accuracy: 0.9159 - val_loss: 0.2448 - val_accuracy: 0.9040 - lr: 2.3151e-05
# Epoch 88/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2274 - accuracy: 0.9166 - val_loss: 0.2439 - val_accuracy: 0.9040 - lr: 2.2920e-05
# Epoch 89/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2260 - accuracy: 0.9168 - val_loss: 0.2431 - val_accuracy: 0.9040 - lr: 2.2692e-05
# Epoch 90/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2246 - accuracy: 0.9171 - val_loss: 0.2422 - val_accuracy: 0.9047 - lr: 2.2466e-05
# Epoch 91/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2232 - accuracy: 0.9176 - val_loss: 0.2413 - val_accuracy: 0.9053 - lr: 2.2243e-05
# Epoch 92/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2219 - accuracy: 0.9181 - val_loss: 0.2404 - val_accuracy: 0.9067 - lr: 2.2022e-05
# Epoch 93/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2206 - accuracy: 0.9187 - val_loss: 0.2394 - val_accuracy: 0.9073 - lr: 2.1802e-05
# Epoch 94/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2193 - accuracy: 0.9196 - val_loss: 0.2383 - val_accuracy: 0.9093 - lr: 2.1586e-05
# Epoch 95/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2180 - accuracy: 0.9203 - val_loss: 0.2372 - val_accuracy: 0.9087 - lr: 2.1371e-05
# Epoch 96/100
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2168 - accuracy: 0.9205 - val_loss: 0.2360 - val_accuracy: 0.9087 - lr: 2.1158e-05
# Epoch 97/100
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2155 - accuracy: 0.9209 - val_loss: 0.2349 - val_accuracy: 0.9100 - lr: 2.0948e-05
# Epoch 98/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2143 - accuracy: 0.9213 - val_loss: 0.2336 - val_accuracy: 0.9100 - lr: 2.0739e-05
# Epoch 99/100
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2130 - accuracy: 0.9218 - val_loss: 0.2324 - val_accuracy: 0.9100 - lr: 2.0533e-05
# Epoch 100/100
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2118 - accuracy: 0.9224 - val_loss: 0.2311 - val_accuracy: 0.9113 - lr: 2.0328e-05

# %% [markdown]
# # Model Evaluation
#
# **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the models performance.**

# %%
# CodeGrade Tag Ex4a

plt.figure()
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend(loc=0)
plt.title('Model Loss')

plt.figure()
plt.plot(history.history['accuracy'], label='Training')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend(loc=0)
plt.title('Model Accuracy')

plt.show()

# %% [markdown]
# **Load the best weights from your model checkpoint, and create plots demonstrating the classification perfomnce for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %%
# CodeGrade Tag Ex4b
model.load_weights(checkpoint_filepath)

y_true = np.concatenate([y for x,y in val_ds])
y_pred = np.argmax(model.predict(val_ds), axis=1)

print(classification_report(y_true, y_pred, target_names = label_dict.keys()))
print(confusion_matrix(y_true, y_pred))

f, ax = plt.subplots(5,5, figsize=(10, 12))
ax = ax.flatten()

x_val = np.concatenate([x for x,y in val_ds])

for i in range(25):
    ax[i].imshow(x_val[i])
    ax[i].set_title(f'Truth = {rev_label_dict[int(y_true[i])]}\nPred = {rev_label_dict[int(y_pred[i])]}')
    ax[i].set_xticks([])
    ax[i].set_yticks([])

plt.show()
# Out:
# 12/12 [==============================] - 0s 6ms/step
#               precision    recall  f1-score   support
#
#          cat       0.89      0.95      0.92       500
#          dog       0.91      0.90      0.90       500
#         wild       0.93      0.89      0.91       500
#
#     accuracy                           0.91      1500
#    macro avg       0.91      0.91      0.91      1500
# weighted avg       0.91      0.91      0.91      1500
#
# [[475  13  12]
#  [ 33 448  19]
#  [ 25  31 444]]
